# %%
x_nums=[1,2,3]
y_nums=[2,4,6]

from pylab import plot, show
plot(x_nums,y_nums,'o')
show()

# %%
nyc_temp=[53.9,56.3,53.4,53.4,54.5,55.8,56.8,55.0,55.3,54.0,56.7,56.4,57.3]
years=range(2000,2013)
plot(years,nyc_temp,marker='o')
show()

# %%
nyc_temp_2000=[31.3,37.3,47.2,51.0,63.5,71.3,72.3,72.7,66.0,57.0,45.3,31.1]
nyc_temp_2006=[40.9,35.7,43.1,55.7,63.1,71.0,77.9,75.8,66.6,56.2,51.9,43.6]
nyc_temp_2012=[37.3,40.9,50.9,54.8,65.1,71.0,78.8,76.6,68.8,58.0,43.9,41.5]
months=range(1,13)
plot(months,nyc_temp_2000,months,nyc_temp_2006,months,nyc_temp_2012)
show()

# %%
plot(months,nyc_temp_2000)
plot(months,nyc_temp_2006)
plot(months,nyc_temp_2012)
show()

# %%
plot(months,nyc_temp_2000,months,nyc_temp_2006,months,nyc_temp_2012)
from pylab import legend
legend([2000,2006,2012])
show()

# %%
from pylab import show, title, xlabel, ylabel, legend

plot(months,nyc_temp_2000,months,nyc_temp_2006,months,nyc_temp_2012)
title('Average Monthly Temprature in NYC')
xlabel('Month')
ylabel('Temp')
legend([2000,2006,2012])

# %%
nyc_temp=[53.9,56.3,56.4,53.4,54.5,55.8,56.8,55.0,55.3,54.0,56.7,56.4,57.3]
plot(nyc_temp,marker= 'o')
from pylab import axis
axis(ymin=0)
# Out:
# (-0.6000000000000001, 12.6, 0.0, 57.495)

# %%
'''
Simple plot using pyplot
'''
import matplotlib.pyplot as plt
def create_graph():
    x_nums=[1,2,3]
    y_nums=[2,4,6]

plt.plot(x_nums,y_nums)
plt.show()

if __name__ == '__main__':
    create_graph()

# %%
from pylab import plot, savefig
x=[1,2,3]
y=[2,4,6]
plot(x,y)
savefig('mygraph.png')

# %%
## Graphing with formulas
'''
The relationship between gravitational force and distance between two bodies
'''

import matplotlib.pyplot as plt
#draw the graph
def draw_graph(x,y):
    plt.plot(x,y,marker='o')
    plt.xlabel('Distance in meters')
    plt.ylabel('Gravitational force in newtons')
    plt.title('Gravitational force and distance')
    plt.show()

def generate_F_r():
    #generat values for r
    r= range(100,1001,50)
    #Empty list f\to store the calculated values of F
    F=[]

    #Constant, G
    G= 6.674*(10**-11)
    #Two masses
    m1=0.5
    m2=1.5
# Calc force and add to list F
    for dist in r:
        force=G*(m1*m2)/(dist**2)
        F.append(force)

    #call the graph function
    draw_graph(r,F)
if __name__=='__main__':
    generate_F_r()

# %% [markdown]
# This will be a projectile motion model
#
# $ v_y=u\sin{\theta}-gt$
#
#
# This is the vertical component
